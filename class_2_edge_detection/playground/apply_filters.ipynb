# %%
import cv2
import numpy as np
image = cv2.imread('./colorimg.jpg')

# %%
gray_img = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
gray_img.shape
# Out:
# (800, 1200)

# %%
sobel_vertical = np.array([[-1, 0, 1],
                           [-2, 0, 2],
                           [-1, 0, 1]])
sobel_vertical
# Out:
# array([[-1,  0,  1],
#        [-2,  0,  2],
#        [-1,  0,  1]])

# %%
#Convolve
rows, cols = gray_img.shape
output_matrix = np.zeros((rows-3+1, cols-3+1))
for i in range(1, rows-1):
    for j in range(1, cols-1):
        region = image[i-1:i+2, j-1:j+2]
        output_matrix[i-1, j-1] = np.sum(region * sobel_vertical)
output_matrix
# Out:
# array([[-228., -228., -228., ...,  516.,  510.,  506.],
#        [-228., -228., -228., ...,  522.,  516.,  508.],
#        [-228., -228., -228., ...,  532.,  527.,  517.],
#        ...,
#        [-264., -264., -262., ..., -658., -665., -668.],
#        [-264., -264., -264., ..., -667., -672., -673.],
#        [-264., -264., -264., ..., -673., -677., -677.]])

# %%
import matplotlib.pyplot as plt


plt.imshow(gray_img)
plt.title('Grayscale Image')
plt.axis('off')
plt.show()
